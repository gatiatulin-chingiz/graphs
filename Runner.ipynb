# %%
import warnings
from src.main import run_pipeline

warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

# %%
# Не пишите run() — IPython automagic превратит это в %run ()
run_pipeline()
