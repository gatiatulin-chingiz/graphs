# %%
import warnings
from src.main import run_pipeline, show_degree_report, visualize

warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

# %%
# 1) Данные + статистика. Без HTML/Gephi (draw=False по умолчанию).
# Не вызывайте run() — IPython превратит это в %run.
run_pipeline()

# %%
# 2) Отчёт ДО отрисовки: hub_degree_n + hub_keywords (регистр не важен).
# Топ-хабов — уже после среза. Пример ключа: «ресо» режет «…РЕСО-ГАРАНТИЯ» + соседей.
show_degree_report(group_index=0, top_n=40)

# %%
# 3) Только после отчёта: Gephi + HTML (мелкие компоненты < bound не пишем).
visualize()
