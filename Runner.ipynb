# %%
import warnings
from src.main import run_pipeline, show_degree_report

warnings.filterwarnings('ignore')

# %load_ext autoreload
# %autoreload 2

# %%
# Только пайплайн и логи. HTML/Gephi → ./output (в ноутбук не выводятся).
# Не вызывайте run() — IPython превратит это в %run.
# Можно пропустить, если ./vars уже есть — сразу ячейка с отчётом.
run_pipeline()

# %%
# Отчёт по степеням группы 0 — выбор порога хабов (режем degree > N).
# Быстро: O(E). Нужен кэш ./vars (после статистики).
show_degree_report(group_index=0, top_n=40)
